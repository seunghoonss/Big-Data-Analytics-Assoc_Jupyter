# %%
# esc 커멘더 모드 / Enter 에디터모드 // 열삭제(dd), 위로 셀추가(a), 아래로 셀추가(b), 복사(c), 붙여넣기(v), 실행후 아래에 셀추가(shift_enter)

# %% [markdown]
# ## 엑셀읽어오기: read_excel()

# %%
import pandas as pd
pd.read_excel("excel_exam.xlsx", sheet_name=0)
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
df2 = pd.read_excel("E01EXAMPLE.xlsx", sheet_name=2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 df2 = pd.read_excel("E01EXAMPLE.xlsx", sheet_name=2)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ## 2. 데이터프레임 병합: merge()

# %%
df3 = df1.merge(df2, how="left")

# %% [markdown]
# ##  3. 클릭보드에 복사: to_clipboard()

# %%
df3.to_clipboard(index=False)
